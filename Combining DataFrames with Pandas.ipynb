# %%
import pandas as pd 
import matplotlib.pyplot as plt 

surveys_df = pd.read_csv('data/surveys.csv', keep_default_na =False, na_values=[''])
# keep_default_na = True(default): appended to the default NaN 
# keep_default_na = False: just leave as blank
# na_values: Additional strings to recognize as NA/NaN
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
species_df = pd.read_csv('data/species.csv', keep_default_na=False, na_values=[''])
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
# read first 10 lines of surveys_df:
survey_sub = surveys_df.head(10)
survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# Grab the last 10 
survey_sub_last10 = surveys_df.tail(10)
survey_sub_last10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# ...

# %%
# reset index of survey_sub_last10
survey_sub_last10.reset_index(drop=False)
# Out:
#    index  record_id  month  day  year  plot_id species_id  sex  \
# 0  35539      35540     12   31  2002       15         PB    F
# 1  35540      35541     12   31  2002       15         PB    F
# 2  35541      35542     12   31  2002       15         PB    F
# 3  35542      35543     12   31  2002       15         PB    F
# 4  35543      35544     12   31  2002       15         US  NaN
# 5  35544      35545     12   31  2002       15         AH  NaN
# 6  35545      35546     12   31  2002       15         AH  NaN
# 7  35546      35547     12   31  2002       10         RM    F
# 8  35547      35548     12   31  2002        7         DO    M
# 9  35548      35549     12   31  2002        5        NaN  NaN
#
#    hindfoot_length  weight
# 0             26.0    23.0
# 1             24.0    31.0
# 2             26.0    29.0
# 3             27.0    34.0
# 4              NaN     NaN
# 5              NaN     NaN
# 6              NaN     NaN
# 7             15.0    14.0
# ...

# %%
survey_sub_last10.reset_index(drop=True)
# drop=True option avoids adding new index column with old index values
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
# Concatenating DataFrames: pd.concat()


# vertical: axis=0, same column and associated column format in both datasets
vertical_stack = pd.concat([survey_sub,survey_sub_last10],axis = 0)
vertical_stack
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
vertical_stack.reset_index(drop=True)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
horizontal_stack = pd.concat([surveys_df.head(), survey_sub_last10], axis=1)
horizontal_stack
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 1            2.0    7.0  16.0  1977.0      3.0         NL    M
# 2            3.0    7.0  16.0  1977.0      2.0         DM    F
# 3            4.0    7.0  16.0  1977.0      7.0         DM    M
# 4            5.0    7.0  16.0  1977.0      3.0         DM    M
# 35539        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35540        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35541        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35542        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35543        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35544        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35545        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35546        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# 35547        NaN    NaN   NaN     NaN      NaN        NaN  NaN
# ...

# %%
# Writing Out Data to CSV

vertical_stack.to_csv('data/out.csv',index=False) #False: exclude index column

# %%
# For kicks read our output back into Python and make sure all looks good
new_output = pd.read_csv('data/out.csv')
new_output
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
# Challenge - Combine Data

survey2001_df = pd.read_csv('data/surveys2001.csv')
survey2001_df
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          31710      31711      1   21  2001        1         PB   F
# 1          31711      31712      1   21  2001        1         DM   M
# 2          31712      31713      1   21  2001        1         PB   M
# 3          31713      31714      1   21  2001        1         DO   M
# 4          31714      31715      1   21  2001        2         OT   M
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 1429       33303      33304     12   15  2001       24         RM   M
# 1430       33304      33305     12   15  2001        7         PB   M
# 1431       33305      33306     12   15  2001        7         OT   M
# 1432       33306      33307     12   15  2001        7         OT   M
# 1433       33307      33308     12   15  2001        7         PP   M
#
#       hindfoot_length  weight
# 0                26.0    25.0
# 1                37.0    43.0
# 2                29.0    44.0
# ...

# %%
survey2002_df = pd.read_csv('data/surveys2002.csv')
survey2002_df
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          33320      33321      1   12  2002        1         DM   M
# 1          33321      33322      1   12  2002        1         DO   M
# 2          33322      33323      1   12  2002        1         PB   M
# 3          33324      33325      1   12  2002        1         DO   M
# 4          33325      33326      1   12  2002        2         OT   F
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 2073       35540      35541     12   31  2002       15         PB   F
# 2074       35541      35542     12   31  2002       15         PB   F
# 2075       35542      35543     12   31  2002       15         PB   F
# 2076       35546      35547     12   31  2002       10         RM   F
# 2077       35547      35548     12   31  2002        7         DO   M
#
#       hindfoot_length  weight
# 0                38.0    44.0
# 1                37.0    58.0
# 2                28.0    45.0
# ...

# %%
combine2001_2002 = pd.concat([survey2001_df,survey2002_df], axis =0)
combine2001_2002
# Out:
#       Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0          31710      31711      1   21  2001        1         PB   F
# 1          31711      31712      1   21  2001        1         DM   M
# 2          31712      31713      1   21  2001        1         PB   M
# 3          31713      31714      1   21  2001        1         DO   M
# 4          31714      31715      1   21  2001        2         OT   M
# ...          ...        ...    ...  ...   ...      ...        ...  ..
# 2073       35540      35541     12   31  2002       15         PB   F
# 2074       35541      35542     12   31  2002       15         PB   F
# 2075       35542      35543     12   31  2002       15         PB   F
# 2076       35546      35547     12   31  2002       10         RM   F
# 2077       35547      35548     12   31  2002        7         DO   M
#
#       hindfoot_length  weight
# 0                26.0    25.0
# 1                37.0    43.0
# 2                29.0    44.0
# ...

# %%
combine2001_2002=combine2001_2002.groupby(['year', 'sex'])['weight'].mean().unstack()
combine2001_2002
# Out:
# sex           F          M
# year
# 2001  36.034771  36.404196
# 2002  33.878761  37.490506

# %%
combine2001_2002.plot(kind='bar')

# %%
# Read in first 10 lines of surveys table
survey_sub = surveys_df.head(10)
survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# Import a small subset of the species data designed for this part of the lesson.
# It is stored in the data folder.
species_sub = pd.read_csv('data/speciesSubset.csv', keep_default_na=False, na_values=[""])
species_sub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %%
species_sub.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
survey_sub.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
# both contain 'species_id', joining by merge

# inner join
merged_inner = pd.merge(left=species_sub, right=survey_sub,left_on='species_id',right_on='species_id')
# For inner joins, the order of the left and right arguments does not matter.
print(merged_inner.shape)
merged_inner
# Out:
# (8, 12)
#   species_id       genus   species    taxa  record_id  month  day  year  \
# 0         DM   Dipodomys  merriami  Rodent          3      7   16  1977
# 1         DM   Dipodomys  merriami  Rodent          4      7   16  1977
# 2         DM   Dipodomys  merriami  Rodent          5      7   16  1977
# 3         DM   Dipodomys  merriami  Rodent          8      7   16  1977
# 4         DM   Dipodomys  merriami  Rodent          9      7   16  1977
# 5         NL     Neotoma  albigula  Rodent          1      7   16  1977
# 6         NL     Neotoma  albigula  Rodent          2      7   16  1977
# 7         PE  Peromyscus  eremicus  Rodent          7      7   16  1977
#
#    plot_id sex  hindfoot_length  weight
# 0        2   F             37.0     NaN
# 1        7   M             36.0     NaN
# 2        3   M             35.0     NaN
# 3        1   M             37.0     NaN
# 4        1   F             34.0     NaN
# 5        2   M             32.0     NaN
# ...

# %%
# left join

merged_left = pd.merge(left=survey_sub, right=species_sub,how='left', left_on='species_id',right_on='species_id')
print(merged_left.shape)
merged_left
# Out:
# (10, 12)
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %%
# species_id PF: NaN
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5          6      7   16  1977        1         PF   M             14.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight genus species taxa
# 5     NaN   NaN     NaN  NaN
# 9     NaN   NaN     NaN  NaN

# %%
# right join

merged_right = pd.merge(left=survey_sub, right=species_sub,how='right', left_on='species_id',right_on='species_id')
print(merged_right.shape)
merged_right
# Out:
# (8, 12)
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# ...

# %%
# Full (outer) join

# the result DataFrame will NaN where data is missing in one of the dataframes. 
# This join type is very rarely used.

merged_out = pd.merge(left=survey_sub, right=species_sub,how='outer', left_on='species_id',right_on='species_id')
print(merged_out.shape)
merged_out
# Out:
# (10, 12)
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          6      7   16  1977        1         PF   M             14.0
# 8         10      7   16  1977        6         PF   F             20.0
# 9          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %%
# Challenge - Distributions

merged_left=pd.merge(left=surveys_df,right=species_df, how='left', on="species_id")
merged_left=merged_left.groupby('plot_id')['taxa'].nunique()
merged_left.plot(kind='bar')
merged_left
# Out:
# plot_id
# 1     3
# 2     4
# 3     3
# 4     2
# 5     3
# 6     3
# 7     3
# 8     4
# 9     3
# 10    3
# 11    4
# 12    3
# 13    4
# 14    3
# 15    4
# 16    3
# 17    4
# 18    3
# 19    4
# 20    3
# 21    4
# 22    4
# 23    3
# 24    3
# Name: taxa, dtype: int64

# %%
# taxa by plot
merged_left=pd.merge(left=surveys_df,right=species_df, how='left', on="species_id")
merged_left=merged_left.groupby(['plot_id','taxa'])['record_id'].count().unstack()
merged_left.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.05))
merged_left
# Out:
# taxa     Bird  Rabbit  Reptile  Rodent
# plot_id
# 1        11.0     2.0      NaN  1976.0
# 2        17.0     3.0      1.0  2170.0
# 3        17.0     5.0      NaN  1786.0
# 4         5.0     NaN      NaN  1955.0
# 5         5.0     1.0      NaN  1144.0
# 6        20.0     NaN      1.0  1541.0
# 7        28.0     NaN      1.0   700.0
# 8        10.0     1.0      1.0  1869.0
# 9        13.0     1.0      NaN  1915.0
# 10       12.0    10.0      NaN   302.0
# 11       10.0     5.0      2.0  1895.0
# 12       31.0     8.0      NaN  2324.0
# 13       48.0     1.0      1.0  1481.0
# 14       17.0     4.0      NaN  1859.0
# 15       23.0     3.0      1.0   997.0
# 16       15.0     3.0      NaN   531.0
# 17        4.0     6.0      1.0  2026.0
# 18       12.0     1.0      NaN  1426.0
# 19       14.0     8.0      1.0  1128.0
# 20       51.0     NaN      2.0  1321.0
# 21       13.0     1.0      1.0  1120.0
# 22       16.0     2.0      1.0  1368.0
# 23       41.0     8.0      NaN   407.0
# ...

# %%
# taxa by sex by plot
merged_left=pd.merge(left=surveys_df,right=species_df, how='left', on="species_id")
merged_left['sex']=merged_left['sex'].fillna('X')
merged_left=merged_left.groupby(['plot_id','sex'])['taxa'].count().unstack()
merged_left.plot(kind='bar',stacked=True)
merged_left
# Out:
# sex         F     M    X
# plot_id
# 1         848  1095   46
# 2         970  1144   77
# 3         893   840   75
# 4         872  1030   58
# 5         527   586   37
# 6         737   764   61
# 7         335   307   87
# 8         840   983   58
# 9         853  1004   72
# 10        141   142   41
# 11        822  1029   61
# 12       1060  1200  103
# 13        628   783  120
# 14        709  1070  101
# 15        481   409  134
# 16        222   273   54
# 17        892  1053   92
# 18        755   626   58
# 19        522   581   48
# 20        650   613  111
# 21        611   451   73
# 22        671   673   43
# 23        165   207   84
# 24        486   485   54

# %%
# Challenge - Diversity Index

plot_info = pd.read_csv("data/plots.csv")
plot_info.groupby("plot_type").count()
# Out:
#                            plot_id
# plot_type
# Control                          8
# Long-term Krat Exclosure         4
# Rodent Exclosure                 6
# Short-term Krat Exclosure        4
# Spectab exclosure                2

# %%
merged_left
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  M|F              NaN
# 35545      35546     12   31  2002       15         AH  M|F              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  M|F              NaN
#
# ...

# %%
merged_plot=pd.merge(left=merged_left,right=plot_info,on='plot_id')
# the number of species for each plot
nspecies = merged_plot.groupby(['plot_id'])['species_id'].nunique()
# the number of individuals
individuals=merged_plot.groupby(['plot_id'])['record_id'].nunique()
# Biodiversity index
biodiversity=pd.concat([nspecies,individuals],axis=1)
biodiversity['diversity_index']=(biodiversity['species_id'])/(biodiversity['record_id'])

# %%
biodiversity
biodiversity['diversity_index'].plot(kind='bar')
plt.ylabel("diversity index")
plt.xlabel('plot_id')
plt.show()
